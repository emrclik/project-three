# %% [markdown]
# ## Files to compare Divvy Subscriber vs NonSubscriber rider activity

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datetime import *
import time

# %%
subs = pd.read_csv('chicago-divvy-bicycle-sharing-data\divvy_Subs_vs_trips.csv')
subs
# Out:
#       Subs                    FROM STATION NAME  \
# 0      436                Canal St & Madison St
# 1      685            Wacker Dr & Washington St
# 2       68                  MLK Jr Dr & 29th St
# 3      379            Columbus Dr & Randolph St
# 4     6098              Streeter Dr & Grand Ave
# 5     2375           Fort Dearborn Dr & 31st St
# 6        5                   State St & 33rd St
# 7      411         Michigan Ave & Washington St
# 8      288         Clinton St & Washington Blvd
# 9     1447            Columbus Dr & Randolph St
# 10     712           Indiana Ave & Roosevelt Rd
# 11    1304            Wabash Ave & Roosevelt Rd
# 12     273                  Canal St & Adams St
# 13     184         Clinton St & Washington Blvd
# 14     601                Calumet Ave & 33rd St
# 15     264                Clark St & Berwyn Ave
# 16     536       Southport Ave & Wellington Ave
# 17    2796         Michigan Ave & Washington St
# ...

# %%
#subs.dtypes

# %%
subs['Subs_Median_Timestamp'] = pd.to_datetime(subs['Subs_Median_Unix_StartTime'], unit= 's')
subs
# Out:
#       Subs                    FROM STATION NAME  \
# 0      436                Canal St & Madison St
# 1      685            Wacker Dr & Washington St
# 2       68                  MLK Jr Dr & 29th St
# 3      379            Columbus Dr & Randolph St
# 4     6098              Streeter Dr & Grand Ave
# 5     2375           Fort Dearborn Dr & 31st St
# 6        5                   State St & 33rd St
# 7      411         Michigan Ave & Washington St
# 8      288         Clinton St & Washington Blvd
# 9     1447            Columbus Dr & Randolph St
# 10     712           Indiana Ave & Roosevelt Rd
# 11    1304            Wabash Ave & Roosevelt Rd
# 12     273                  Canal St & Adams St
# 13     184         Clinton St & Washington Blvd
# 14     601                Calumet Ave & 33rd St
# 15     264                Clark St & Berwyn Ave
# 16     536       Southport Ave & Wellington Ave
# 17    2796         Michigan Ave & Washington St
# ...

# %%
subs.to_csv('chicago-divvy-bicycle-sharing-data\divvy_Subs_VS_trips.csv')

# %% [markdown]
# ## NONSUBSCRIBER DATA

# %%
non_subs = pd.read_csv('chicago-divvy-bicycle-sharing-data\divvy_NonSubs_vs_trips.csv')
non_subs
# Out:
#      NonSub                FROM STATION NAME                  TO STATION NAME  \
# 0        45        Lake Shore Dr & Monroe St          Streeter Dr & Grand Ave
# 1        96          Streeter Dr & Grand Ave          Streeter Dr & Grand Ave
# 2        13        Lake Shore Dr & Monroe St        Lake Shore Dr & Monroe St
# 3        68          Streeter Dr & Grand Ave       Lake Shore Dr & North Blvd
# 4       101          Streeter Dr & Grand Ave        Lake Shore Dr & Monroe St
# 5        78       Lake Shore Dr & North Blvd          Streeter Dr & Grand Ave
# 6       338          Streeter Dr & Grand Ave              Theater on the Lake
# 7       130              Theater on the Lake          Streeter Dr & Grand Ave
# 8       120                   Dusable Harbor          Streeter Dr & Grand Ave
# 9       296          Streeter Dr & Grand Ave                  Millennium Park
# 10       24          Streeter Dr & Grand Ave            Michigan Ave & Oak St
# ...

# %%
non_subs.dtypes
# Out:
# NonSub                            int64
# FROM STATION NAME                object
# TO STATION NAME                  object
# NonSub_Trip_Duration            float64
# NonSub_Trip                      object
# NonSub_Start_Lat                float64
# NonSub_Start_Long               float64
# NonSub_End_Lat                  float64
# NonSub_End_Long                 float64
# NonSub_Median_Duration_Mins     float64
# NonSub_Median_Unix_StartTime      int64
# NonSub_Size                       int64
# dtype: object

# %%
non_subs['NonSub_Median_Timestamp'] = pd.to_datetime(non_subs['NonSub_Median_Unix_StartTime'], unit= 's')
non_subs
# Out:
#      NonSub                FROM STATION NAME                  TO STATION NAME  \
# 0        45        Lake Shore Dr & Monroe St          Streeter Dr & Grand Ave
# 1        96          Streeter Dr & Grand Ave          Streeter Dr & Grand Ave
# 2        13        Lake Shore Dr & Monroe St        Lake Shore Dr & Monroe St
# 3        68          Streeter Dr & Grand Ave       Lake Shore Dr & North Blvd
# 4       101          Streeter Dr & Grand Ave        Lake Shore Dr & Monroe St
# 5        78       Lake Shore Dr & North Blvd          Streeter Dr & Grand Ave
# 6       338          Streeter Dr & Grand Ave              Theater on the Lake
# 7       130              Theater on the Lake          Streeter Dr & Grand Ave
# 8       120                   Dusable Harbor          Streeter Dr & Grand Ave
# 9       296          Streeter Dr & Grand Ave                  Millennium Park
# 10       24          Streeter Dr & Grand Ave            Michigan Ave & Oak St
# ...

# %%
non_subs.to_csv('chicago-divvy-bicycle-sharing-data\divvy_NonSubs_VS_trips.csv')
