# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=  pd.read_csv('chicago-divvy-bicycle-sharing-data\divvy_subscribers_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0   TRIP ID           START TIME            STOP TIME  \
# 0           0  13842911  2017-05-01 00:02:00  2017-05-01 00:07:00
# 1           1  13864102  2017-05-03 08:52:00  2017-05-03 08:57:00
# 2           2  13909116  2017-05-07 13:50:00  2017-05-07 13:55:00
# 3           3  14145433  2017-05-24 19:38:00  2017-05-24 19:44:00
# 4           4  14145430  2017-05-24 19:38:00  2017-05-24 19:44:00
#
#    FROM STATION NAME     TO STATION NAME GENDER  Start Date Start Time  \
# 0  900 W Harrison St  May St & Taylor St   Male  2017-05-01   00:02:00
# 1  900 W Harrison St  May St & Taylor St   Male  2017-05-03   08:52:00
# 2  900 W Harrison St  May St & Taylor St   Male  2017-05-07   13:50:00
# 3  900 W Harrison St  May St & Taylor St   Male  2017-05-24   19:38:00
# 4  900 W Harrison St  May St & Taylor St   Male  2017-05-24   19:38:00
#
#      End Date     ...     StartTime_Unix  Trip_Duration  Age  \
# 0  2017-05-01     ...         1493596920       4.250000   21
# ...

# %%
#Code Gender ( 1=Male, 2= Female)
df['gender'] = df['GENDER'].apply({'Male':1, 'Female': 2}.get)
df.head()
# Out:
#    Unnamed: 0   TRIP ID           START TIME            STOP TIME  \
# 0           0  13842911  2017-05-01 00:02:00  2017-05-01 00:07:00
# 1           1  13864102  2017-05-03 08:52:00  2017-05-03 08:57:00
# 2           2  13909116  2017-05-07 13:50:00  2017-05-07 13:55:00
# 3           3  14145433  2017-05-24 19:38:00  2017-05-24 19:44:00
# 4           4  14145430  2017-05-24 19:38:00  2017-05-24 19:44:00
#
#    FROM STATION NAME     TO STATION NAME GENDER  Start Date Start Time  \
# 0  900 W Harrison St  May St & Taylor St   Male  2017-05-01   00:02:00
# 1  900 W Harrison St  May St & Taylor St   Male  2017-05-03   08:52:00
# 2  900 W Harrison St  May St & Taylor St   Male  2017-05-07   13:50:00
# 3  900 W Harrison St  May St & Taylor St   Male  2017-05-24   19:38:00
# 4  900 W Harrison St  May St & Taylor St   Male  2017-05-24   19:38:00
#
#      End Date   ...   Trip_Duration  Age  \
# 0  2017-05-01   ...        4.250000   21
# 1  2017-05-03   ...        4.666667   30
# ...

# %%
#list(df.columns.values)

# %%
#Clean DataFrame:
df = df.drop('TRIP ID', axis=1)
df = df.drop('START TIME', axis=1)
df = df.drop('STOP TIME', axis=1)
df = df.drop('FROM STATION NAME', axis=1)
df = df.drop('TO STATION NAME', axis=1)
df = df.drop('GENDER', axis=1)
df = df.drop('Start Date', axis=1)
df = df.drop('Start Time', axis=1)
df = df.drop('End Date', axis=1)
df = df.drop('End Time', axis=1)
df = df.drop('StopTime_Hour', axis=1)
df = df.drop('StartTime_Unix', axis=1)
df = df.drop('Trip', axis=1)
df = df.drop('Median_Duration_Mins', axis=1)
df = df.drop('Median_Unix_StartTime', axis=1)
df = df.drop('Size', axis=1)
df = df.drop('Median_Age', axis=1)

# %%
twenties = []
for val in df['Age']:
    if val < 30 and val > 19:
        twenties.append(1)
    else:
        twenties.append(0)
        
df['twenties'] = twenties
df.head()
# Out:
#    Unnamed: 0  StartTime_Hour  Trip_Duration  Age          Start_Coords  \
# 0           0               0       4.250000   21  41.874675,-87.650019
# 1           1               8       4.666667   30  41.874675,-87.650019
# 2           2              13       5.083333   25  41.874675,-87.650019
# 3           3              19       5.750000   25  41.874675,-87.650019
# 4           4              19       6.000000   24  41.874675,-87.650019
#
#                End_Coords  gender  twenties
# 0  41.8694821,-87.6554864     1.0         1
# 1  41.8694821,-87.6554864     1.0         0
# 2  41.8694821,-87.6554864     1.0         1
# 3  41.8694821,-87.6554864     1.0         1
# 4  41.8694821,-87.6554864     1.0         1

# %%
df.to_csv('chicago-divvy-bicycle-sharing-data\divvy_cleaned_neuralnetwork.csv')
