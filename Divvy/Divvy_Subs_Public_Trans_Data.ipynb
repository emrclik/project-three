# %% [markdown]
# ## Divvy Bike Share May 2017 - Subscriber Trip- Public Transportation Data

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
#Import CSV
bike_trips= pd.read_csv("chicago-divvy-bicycle-sharing-data\divvy_subscribers_trips.csv")
bike_trips.head()
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
# 4        6098      15.633333
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
# 4  41.892278000000005,-87.612043|41.926277,-87.63...
#
#                     Start_Coords                             End_Coords  \
# 0  41.882090999999996,-87.639833               41.88389277,-87.62464914
# 1       41.88327159,-87.63731329               41.88389277,-87.62464914
# 2              41.842052,-87.617          41.834734000000005,-87.625813
# 3   41.884728,-87.61952099999999  41.883379999999995,-87.64116999999999
# 4  41.892278000000005,-87.612043                   41.926277,-87.630834
#
#    Median_Duration_Mins  Median_Unix_StartTime  Median_Age  Size  \
# 0              7.291667             1494835500        30.0   286
# 1              6.200000             1494919260        32.0   259
# 2              8.208333             1495117590        51.5   238
# 3              9.200000             1494950040        31.0   231
# 4             19.016667             1495185600        36.0   207
#
#    Public_Duration
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
bike_trips["Distance"] = ''
bike_trips.head()
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
# 4        6098      15.633333
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
# 4  41.892278000000005,-87.612043|41.926277,-87.63...
#
#                     Start_Coords                             End_Coords  \
# 0  41.882090999999996,-87.639833               41.88389277,-87.62464914
# 1       41.88327159,-87.63731329               41.88389277,-87.62464914
# 2              41.842052,-87.617          41.834734000000005,-87.625813
# 3   41.884728,-87.61952099999999  41.883379999999995,-87.64116999999999
# 4  41.892278000000005,-87.612043                   41.926277,-87.630834
#
#    Median_Duration_Mins  Median_Unix_StartTime  Median_Age  Size  \
# 0              7.291667             1494835500        30.0   286
# 1              6.200000             1494919260        32.0   259
# 2              8.208333             1495117590        51.5   238
# 3              9.200000             1494950040        31.0   231
# 4             19.016667             1495185600        36.0   207
#
#    Public_Duration Distance
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
### FOR TESTING ONLY ###
# create a test dataframe
test_df = bike_trips.iloc[0:4]
test_df
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
#
#                     Start_Coords                             End_Coords  \
# 0  41.882090999999996,-87.639833               41.88389277,-87.62464914
# 1       41.88327159,-87.63731329               41.88389277,-87.62464914
# 2              41.842052,-87.617          41.834734000000005,-87.625813
# 3   41.884728,-87.61952099999999  41.883379999999995,-87.64116999999999
#
#    Median_Duration_Mins  Median_Unix_StartTime  Median_Age  Size  \
# 0              7.291667             1494835500        30.0   286
# 1              6.200000             1494919260        32.0   259
# 2              8.208333             1495117590        51.5   238
# 3              9.200000             1494950040        31.0   231
#
#    Public_Duration Distance
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN

# %%
# parameters for the API call
params = {
    "mode": "transit",
    "key": gkey
}

count = 0

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Use the start and end coordinates to get the directions
####### CHANGE THE DATAFRAME FROM TEST ############
for index, row in test_df.iterrows():
    
    origin = row["Start_Coords"]
    destination = row["End_Coords"]
    departure_time = row["Median_Unix_StartTime"]

    # change location each iteration while leaving original params in place
    params["origin"] = f"{origin}"
    params["destination"] = f"{destination}"
    params["departure_time"] = f"{departure_time}"
    
    base_url = "https://maps.googleapis.com/maps/api/directions/json"

    # make request and print url
    directions = requests.get(base_url, params=params)
    print(directions.url)

    count += 1
    print(count)
    
    # convert to json
    directions = directions.json()

    try:
        test_df.set_value(index, "Public_Duration",
                            directions["routes"][0]["legs"][0]["duration"]["value"])
        test_df.set_value(index, "Distance",
                            directions["routes"][0]["legs"][0]["distance"]["value"])
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
print ("---------------------------------------")
print ("Data Retrieval Complete")
print ("---------------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# https://maps.googleapis.com/maps/api/directions/json?mode=transit&key=AIzaSyCPQyGwsy0pGDl3BzR76vP83smRHFvFOxo&origin=41.882090999999996%2C-87.639833&destination=41.88389277%2C-87.62464914&departure_time=1494835500
# 1
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/directions/json?mode=transit&key=AIzaSyCPQyGwsy0pGDl3BzR76vP83smRHFvFOxo&origin=41.88327159%2C-87.63731329&destination=41.88389277%2C-87.62464914&departure_time=1494919260
# 2
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/directions/json?mode=transit&key=AIzaSyCPQyGwsy0pGDl3BzR76vP83smRHFvFOxo&origin=41.842052%2C-87.617&destination=41.834734000000005%2C-87.625813&departure_time=1495117590
# 3
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/directions/json?mode=transit&key=AIzaSyCPQyGwsy0pGDl3BzR76vP83smRHFvFOxo&origin=41.884728%2C-87.61952099999999&destination=41.883379999999995%2C-87.64116999999999&departure_time=1494950040
# 4
# Missing field/result... skipping.
# ---------------------------------------
# Data Retrieval Complete
# ---------------------------------------

# %%
bike_trips.head()
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
# 4        6098      15.633333
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
# 4  41.892278000000005,-87.612043|41.926277,-87.63...
#
#                     Start_Coords                             End_Coords  \
# 0  41.882090999999996,-87.639833               41.88389277,-87.62464914
# 1       41.88327159,-87.63731329               41.88389277,-87.62464914
# 2              41.842052,-87.617          41.834734000000005,-87.625813
# 3   41.884728,-87.61952099999999  41.883379999999995,-87.64116999999999
# 4  41.892278000000005,-87.612043                   41.926277,-87.630834
#
#    Median_Duration_Mins  Median_Unix_StartTime  Median_Age  Size  \
# 0              7.291667             1494835500        30.0   286
# 1              6.200000             1494919260        32.0   259
# 2              8.208333             1495117590        51.5   238
# 3              9.200000             1494950040        31.0   231
# 4             19.016667             1495185600        36.0   207
#
#    Public_Duration Distance
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# convert the public transportation duration from seconds to minutes# conver 
bike_trips['Public_Duration_Mins'] = bike_trips['Public_Duration'] / 60
bike_trips.head(10)
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
# 4        6098      15.633333
# 5        2375      10.566667
# 6           5       9.416667
# 7         411       5.633333
# 8         288       5.466667
# 9        1447      10.383333
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
# 4  41.892278000000005,-87.612043|41.926277,-87.63...
# 5  41.838556,-87.60821800000001|41.856268,-87.613348
# 6    41.834734000000005,-87.625813|41.842052,-87.617
# 7  41.88389277,-87.62464914|41.883379999999995,-8...
# 8  41.883379999999995,-87.64116999999999|41.88389...
# 9  41.884728,-87.61952099999999|41.88209099999999...
#
#                             Start_Coords  \
# 0          41.882090999999996,-87.639833
# 1               41.88327159,-87.63731329
# 2                      41.842052,-87.617
# 3           41.884728,-87.61952099999999
# 4          41.892278000000005,-87.612043
# 5           41.838556,-87.60821800000001
# 6          41.834734000000005,-87.625813
# 7               41.88389277,-87.62464914
# 8  41.883379999999995,-87.64116999999999
# 9           41.884728,-87.61952099999999
#
#                               End_Coords  Median_Duration_Mins  \
# 0               41.88389277,-87.62464914              7.291667
# 1               41.88389277,-87.62464914              6.200000
# 2          41.834734000000005,-87.625813              8.208333
# 3  41.883379999999995,-87.64116999999999              9.200000
# 4                   41.926277,-87.630834             19.016667
# 5                   41.856268,-87.613348             13.083333
# 6                      41.842052,-87.617              8.766667
# 7  41.883379999999995,-87.64116999999999              7.883333
# 8               41.88389277,-87.62464914              7.900000
# 9          41.882090999999996,-87.639833              9.333333
#
#    Median_Unix_StartTime  Median_Age  Size  Public_Duration Distance  \
# 0             1494835500        30.0   286              NaN
# 1             1494919260        32.0   259              NaN
# 2             1495117590        51.5   238              NaN
# 3             1494950040        31.0   231              NaN
# 4             1495185600        36.0   207              NaN
# 5             1495382160        45.0   205              NaN
# 6             1494950040        47.0   199              NaN
# 7             1494955320        32.0   194              NaN
# 8             1494920190        33.0   192              NaN
# 9             1494936720        28.0   189              NaN
#
#    Public_Duration_Mins
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN

# %%
# add a column calculating the time saved
bike_trips['Time_Saved'] = bike_trips['Public_Duration_Mins'] - bike_trips['Median_Duration_Mins']
bike_trips.head()
# Out:
#    Unnamed: 0  Trip_Duration  \
# 0         436       5.700000
# 1         685       5.000000
# 2          68       6.583333
# 3         379       9.666667
# 4        6098      15.633333
#
#                                                 Trip  \
# 0  41.882090999999996,-87.639833|41.88389277,-87....
# 1  41.88327159,-87.63731329|41.88389277,-87.62464914
# 2    41.842052,-87.617|41.834734000000005,-87.625813
# 3  41.884728,-87.61952099999999|41.88337999999999...
# 4  41.892278000000005,-87.612043|41.926277,-87.63...
#
#                     Start_Coords                             End_Coords  \
# 0  41.882090999999996,-87.639833               41.88389277,-87.62464914
# 1       41.88327159,-87.63731329               41.88389277,-87.62464914
# 2              41.842052,-87.617          41.834734000000005,-87.625813
# 3   41.884728,-87.61952099999999  41.883379999999995,-87.64116999999999
# 4  41.892278000000005,-87.612043                   41.926277,-87.630834
#
#    Median_Duration_Mins  Median_Unix_StartTime  Median_Age  Size  \
# 0              7.291667             1494835500        30.0   286
# 1              6.200000             1494919260        32.0   259
# 2              8.208333             1495117590        51.5   238
# 3              9.200000             1494950040        31.0   231
# 4             19.016667             1495185600        36.0   207
#
#    Public_Duration Distance  Public_Duration_Mins  Time_Saved
# 0              NaN                            NaN         NaN
# 1              NaN                            NaN         NaN
# 2              NaN                            NaN         NaN
# 3              NaN                            NaN         NaN
# 4              NaN                            NaN         NaN
